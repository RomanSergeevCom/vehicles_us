# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px

# %%
data = pd.read_csv('vehicles_us.csv')
#51525 rows × 13 columns
data.dtypes
# Out:
# price             int64
# model_year      float64
# model            object
# condition        object
# cylinders       float64
# fuel             object
# odometer        float64
# transmission     object
# type             object
# paint_color      object
# is_4wd          float64
# date_posted      object
# days_listed       int64
# dtype: object

# %%
data
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV         NaN     1.0  2018-06-23           19
# 1        automatic  pickup       white     1.0  2018-10-19           50
# 2        automatic   sedan         red     NaN  2019-02-07           79
# 3        automatic  pickup         NaN     NaN  2019-03-22            9
# 4        automatic   sedan       black     NaN  2019-04-02           28
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     NaN  2018-10-03           37
# 51521    automatic   sedan       white     NaN  2018-11-14           22
# 51522    automatic   sedan        blue     NaN  2018-11-15           32
# 51523    automatic   sedan       black     NaN  2018-07-02           71
# 51524    automatic   sedan         NaN     NaN  2018-06-05           10
#
# [51525 rows x 13 columns]

# %%
#Let's find gaps and display them in a convenient format.
na = data.isna().sum()
na_perc = round ((data.isna().mean() * 100), 2)

display (pd.DataFrame({"Number of missing values": na, "% missing values":na_perc}).style.format('{:.2f}').background_gradient('coolwarm'))
print (f'Total columns: {len(na)}, without missing values: {(na == 0).sum()}, with missing values: {(na != 0).sum()}')
# Out:
# <style type="text/css">
# #T_d341e_row0_col0, #T_d341e_row0_col1, #T_d341e_row2_col0, #T_d341e_row2_col1, #T_d341e_row3_col0, #T_d341e_row3_col1, #T_d341e_row5_col0, #T_d341e_row5_col1, #T_d341e_row7_col0, #T_d341e_row7_col1, #T_d341e_row8_col0, #T_d341e_row8_col1, #T_d341e_row11_col0, #T_d341e_row11_col1, #T_d341e_row12_col0, #T_d341e_row12_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d341e_row1_col0, #T_d341e_row1_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d341e_row4_col0, #T_d341e_row4_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d341e_row6_col0, #T_d341e_row6_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_d341e_row9_col0, #T_d341e_row9_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_d341e_row10_col0, #T_d341e_row10_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d341e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d341e_level0_col0" class="col_heading level0 col0" >Number of missing values</th>
#       <th id="T_d341e_level0_col1" class="col_heading level0 col1" >% missing values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d341e_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_d341e_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_d341e_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row1" class="row_heading level0 row1" >model_year</th>
#       <td id="T_d341e_row1_col0" class="data row1 col0" >3619.00</td>
#       <td id="T_d341e_row1_col1" class="data row1 col1" >7.02</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row2" class="row_heading level0 row2" >model</th>
#       <td id="T_d341e_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_d341e_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row3" class="row_heading level0 row3" >condition</th>
#       <td id="T_d341e_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_d341e_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row4" class="row_heading level0 row4" >cylinders</th>
#       <td id="T_d341e_row4_col0" class="data row4 col0" >5260.00</td>
#       <td id="T_d341e_row4_col1" class="data row4 col1" >10.21</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row5" class="row_heading level0 row5" >fuel</th>
#       <td id="T_d341e_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_d341e_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row6" class="row_heading level0 row6" >odometer</th>
#       <td id="T_d341e_row6_col0" class="data row6 col0" >7892.00</td>
#       <td id="T_d341e_row6_col1" class="data row6 col1" >15.32</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row7" class="row_heading level0 row7" >transmission</th>
#       <td id="T_d341e_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_d341e_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row8" class="row_heading level0 row8" >type</th>
#       <td id="T_d341e_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_d341e_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row9" class="row_heading level0 row9" >paint_color</th>
#       <td id="T_d341e_row9_col0" class="data row9 col0" >9267.00</td>
#       <td id="T_d341e_row9_col1" class="data row9 col1" >17.99</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row10" class="row_heading level0 row10" >is_4wd</th>
#       <td id="T_d341e_row10_col0" class="data row10 col0" >25953.00</td>
#       <td id="T_d341e_row10_col1" class="data row10 col1" >50.37</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row11" class="row_heading level0 row11" >date_posted</th>
#       <td id="T_d341e_row11_col0" class="data row11 col0" >0.00</td>
#       <td id="T_d341e_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d341e_level0_row12" class="row_heading level0 row12" >days_listed</th>
#       <td id="T_d341e_row12_col0" class="data row12 col0" >0.00</td>
#       <td id="T_d341e_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#   </tbody>
# </table>
# Total columns: 13, without missing values: 8, with missing values: 5

# %%
data['model_year'].value_counts()
# Out:
# 2013.0    3549
# 2012.0    3468
# 2014.0    3448
# 2011.0    3375
# 2015.0    3323
#           ...
# 1948.0       1
# 1961.0       1
# 1936.0       1
# 1949.0       1
# 1929.0       1
# Name: model_year, Length: 68, dtype: int64

# %%
data['cylinders'].value_counts()
# Out:
# 8.0     15844
# 6.0     15700
# 4.0     13864
# 10.0      549
# 5.0       272
# 3.0        34
# 12.0        2
# Name: cylinders, dtype: int64

# %%
data['odometer'].value_counts()
# Out:
# 0.0         185
# 140000.0    183
# 120000.0    179
# 130000.0    178
# 160000.0    167
#            ...
# 138580.0      1
# 94624.0       1
# 123321.0      1
# 202627.0      1
# 139573.0      1
# Name: odometer, Length: 17762, dtype: int64

# %%
data['paint_color'].value_counts()
# Out:
# white     10029
# black      7692
# silver     6244
# grey       5037
# blue       4475
# red        4421
# green      1396
# brown      1223
# custom     1153
# yellow      255
# orange      231
# purple      102
# Name: paint_color, dtype: int64

# %%
data['is_4wd'].value_counts()
# Out:
# 1.0    25572
# Name: is_4wd, dtype: int64

# %%
# For model_year
data['model_year'] = data.groupby('model')['model_year'].transform(lambda x: x.fillna(x.median()))

# For cylinders
data['cylinders'] = data.groupby('model')['cylinders'].transform(lambda x: x.fillna(x.median()))

# For odometer
data['odometer'] = data.groupby(['model_year', 'model'])['odometer'].transform(lambda x: x.fillna(x.mean()))

# For paint_color
data['paint_color'] = data['paint_color'].fillna('no info')

# %%
#Verify that there are no more missing values

na = data.isna().sum()
na_perc = round ((data.isna().mean() * 100), 2)

display (pd.DataFrame({"Number of missing values": na, "% missing values":na_perc}).style.format('{:.2f}').background_gradient('coolwarm'))
print (f'Total columns: {len(na)}, without missing values: {(na == 0).sum()}, with missing values: {(na != 0).sum()}')
# Out:
# <style type="text/css">
# #T_56629_row0_col0, #T_56629_row0_col1, #T_56629_row1_col0, #T_56629_row1_col1, #T_56629_row2_col0, #T_56629_row2_col1, #T_56629_row3_col0, #T_56629_row3_col1, #T_56629_row4_col0, #T_56629_row4_col1, #T_56629_row5_col0, #T_56629_row5_col1, #T_56629_row6_col0, #T_56629_row6_col1, #T_56629_row7_col0, #T_56629_row7_col1, #T_56629_row8_col0, #T_56629_row8_col1, #T_56629_row9_col0, #T_56629_row9_col1, #T_56629_row11_col0, #T_56629_row11_col1, #T_56629_row12_col0, #T_56629_row12_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_56629_row10_col0, #T_56629_row10_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_56629">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56629_level0_col0" class="col_heading level0 col0" >Number of missing values</th>
#       <th id="T_56629_level0_col1" class="col_heading level0 col1" >% missing values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56629_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_56629_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_56629_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row1" class="row_heading level0 row1" >model_year</th>
#       <td id="T_56629_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_56629_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row2" class="row_heading level0 row2" >model</th>
#       <td id="T_56629_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_56629_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row3" class="row_heading level0 row3" >condition</th>
#       <td id="T_56629_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_56629_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row4" class="row_heading level0 row4" >cylinders</th>
#       <td id="T_56629_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_56629_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row5" class="row_heading level0 row5" >fuel</th>
#       <td id="T_56629_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_56629_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row6" class="row_heading level0 row6" >odometer</th>
#       <td id="T_56629_row6_col0" class="data row6 col0" >83.00</td>
#       <td id="T_56629_row6_col1" class="data row6 col1" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row7" class="row_heading level0 row7" >transmission</th>
#       <td id="T_56629_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_56629_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row8" class="row_heading level0 row8" >type</th>
#       <td id="T_56629_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_56629_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row9" class="row_heading level0 row9" >paint_color</th>
#       <td id="T_56629_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_56629_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row10" class="row_heading level0 row10" >is_4wd</th>
#       <td id="T_56629_row10_col0" class="data row10 col0" >25953.00</td>
#       <td id="T_56629_row10_col1" class="data row10 col1" >50.37</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row11" class="row_heading level0 row11" >date_posted</th>
#       <td id="T_56629_row11_col0" class="data row11 col0" >0.00</td>
#       <td id="T_56629_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_56629_level0_row12" class="row_heading level0 row12" >days_listed</th>
#       <td id="T_56629_row12_col0" class="data row12 col0" >0.00</td>
#       <td id="T_56629_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#   </tbody>
# </table>
# Total columns: 13, without missing values: 11, with missing values: 2

# %%
data
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500      2011.0      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas  175165.5
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas  105229.2
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV     no info     1.0  2018-06-23           19
# 1        automatic  pickup       white     1.0  2018-10-19           50
# 2        automatic   sedan         red     NaN  2019-02-07           79
# 3        automatic  pickup     no info     NaN  2019-03-22            9
# 4        automatic   sedan       black     NaN  2019-04-02           28
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     NaN  2018-10-03           37
# 51521    automatic   sedan       white     NaN  2018-11-14           22
# 51522    automatic   sedan        blue     NaN  2018-11-15           32
# 51523    automatic   sedan       black     NaN  2018-07-02           71
# 51524    automatic   sedan     no info     NaN  2018-06-05           10
#
# [51525 rows x 13 columns]

# %%
# Create the scatter plot
fig = px.scatter(data, x='model_year', y='odometer')

# Display the plot
st.plotly_chart(fig)
# Out:
# DeltaGenerator()
